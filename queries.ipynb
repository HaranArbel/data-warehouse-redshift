# %%
# %load_ext sql

# %%
import configparser
import psycopg2
import sqlalchemy

# %%
config = configparser.ConfigParser()
config.read('dwh.cfg')

DWH_DB = config.get("CLUSTER", "DB_NAME")
DWH_DB_USER = config.get("CLUSTER", "DB_USER")
DWH_DB_PASSWORD = config.get("CLUSTER", "DB_PASSWORD")
DWH_PORT = config.get("CLUSTER", "DB_PORT")
DWH_HOST = config.get("CLUSTER", "HOST")

# %%
conn_string = "postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_HOST, DWH_PORT, DWH_DB)
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://awsuser:Aa12345678@redshift-cluster-2.ccjtiiejbjy6.us-west-2.redshift.amazonaws.com:5439/dev

# %%
# %%sql
# SELECT * FROM user_dim;
# Out:
#  * postgresql://awsuser:***@redshift-cluster-2.ccjtiiejbjy6.us-west-2.redshift.amazonaws.com:5439/dev
# 104 rows affected.
# [('100', 'Adler', 'Barrera', 'M', 'free'),
#  ('11', 'Christian', 'Porter', 'F', 'free'),
#  ('16', 'Rylan', 'George', 'M', 'free'),
#  ('17', 'Makinley', 'Jones', 'F', 'free'),
#  ('2', 'Jizelle', 'Benjamin', 'F', 'free'),
#  ('24', 'Layla', 'Griffin', 'F', 'paid'),
#  ('34', 'Evelin', 'Ayala', 'F', 'free'),
#  ('36', 'Matthew', 'Jones', 'M', 'paid'),
#  ('42', 'Harper', 'Barrett', 'M', 'paid'),
#  ('44', 'Aleena', 'Kirby', 'F', 'paid'),
#  ('47', 'Kimber', 'Norris', 'F', 'free'),
#  ('49', 'Chloe', 'Cuevas', 'F', 'free'),
#  ('53', 'Celeste', 'Williams', 'F', 'free'),
#  ('54', 'Kaleb', 'Cook', 'M', 'free'),
#  ('59', 'Lily', 'Cooper', 'F', 'free'),
#  ('65', 'Amiya', 'Davidson', 'F', 'paid'),
#  ('70', 'Jaleah', 'Hayes', 'F', 'paid'),
#  ('76', 'Jayden', 'Duffy', 'F', 'free'),
#  ('78', 'Chloe', 'Roth', 'F', 'free'),
#  ('81', 'Sienna', 'Colon', 'F', 'free'),
#  ('82', 'Avery', 'Martinez', 'F', 'paid'),
#  ('85', 'Kinsley', 'Young', 'F', 'free'),
#  ('9', 'Wyatt', 'Scott', 'M', 'free'),
#  ('94', 'Noah', 'Chavez', 'M', 'free'),
#  ('95', 'Sara', 'Johnson', 'F', 'paid'),
#  ('98', 'Jordyn', 'Powell', 'F', 'free'),
#  ('10', 'Sylvie', 'Cruz', 'F', 'free'),
#  ('15', 'Lily', 'Koch', 'F', 'free'),
#  ('23', 'Morris', 'Gilmore', 'M', 'free'),
#  ('25', 'Jayden', 'Graves', 'M', 'paid'),
#  ('26', 'Ryan', 'Smith', 'M', 'free'),
#  ('27', 'Carlos', 'Carter', 'M', 'free'),
#  ('28', 'Brantley', 'West', 'M', 'free'),
#  ('29', 'Jacqueline', 'Lynch', 'F', 'paid'),
#  ('30', 'Avery', 'Watkins', 'F', 'paid'),
#  ('32', 'Lily', 'Burns', 'F', 'free'),
#  ('38', 'Gianna', 'Jones', 'F', 'free'),
#  ('39', 'Walter', 'Frye', 'M', 'free'),
#  ('51', 'Maia', 'Burke', 'F', 'free'),
#  ('55', 'Martin', 'Johnson', 'M', 'free'),
#  ('58', 'Emily', 'Benson', 'F', 'paid'),
#  ('6', 'Cecilia', 'Owens', 'F', 'free'),
#  ('69', 'Anabelle', 'Simpson', 'F', 'free'),
#  ('72', 'Hayden', 'Brock', 'F', 'paid'),
#  ('74', 'Braden', 'Parker', 'M', 'free'),
#  ('75', 'Joseph', 'Gutierrez', 'M', 'free'),
#  ('80', 'Tegan', 'Levine', 'F', 'free'),
#  ('80', 'Tegan', 'Levine', 'F', 'paid'),
#  ('85', 'Kinsley', 'Young', 'F', 'paid'),
#  ('89', 'Kynnedi', 'Sanchez', 'F', 'free'),
#  ('90', 'Andrea', 'Butler', 'F', 'free'),
#  ('92', 'Ryann', 'Smith', 'F', 'free'),
#  ('12', 'Austin', 'Rosales', 'M', 'free'),
#  ('15', 'Lily', 'Koch', 'F', 'paid'),
#  ('18', 'Jacob', 'Rogers', 'M', 'free'),
#  ('19', 'Zachary', 'Thomas', 'M', 'free'),
#  ('22', 'Sean', 'Wilson', 'F', 'free'),
#  ('29', 'Jacqueline', 'Lynch', 'F', 'free'),
#  ('33', 'Bronson', 'Harris', 'M', 'free'),
#  ('37', 'Jordan', 'Hicks', 'F', 'free'),
#  ('40', 'Tucker', 'Garrison', 'M', 'free'),
#  ('41', 'Brayden', 'Clark', 'M', 'free'),
#  ('43', 'Jahiem', 'Miles', 'M', 'free'),
#  ('49', 'Chloe', 'Cuevas', 'F', 'paid'),
#  ('5', 'Elijah', 'Davis', 'M', 'free'),
#  ('50', 'Ava', 'Robinson', 'F', 'free'),
#  ('60', 'Devin', 'Larson', 'M', 'free'),
#  ('62', 'Connar', 'Moreno', 'M', 'free'),
#  ('7', 'Adelyn', 'Jordan', 'F', 'free'),
#  ('71', 'Ayleen', 'Wise', 'F', 'free'),
#  ('73', 'Jacob', 'Klein', 'M', 'paid'),
#  ('83', 'Stefany', 'White', 'F', 'free'),
#  ('86', 'Aiden', 'Hess', 'M', 'free'),
#  ('88', 'Mohammad', 'Rodriguez', 'M', 'free'),
#  ('88', 'Mohammad', 'Rodriguez', 'M', 'paid'),
#  ('96', 'Cierra', 'Finley', 'F', 'free'),
#  ('97', 'Kate', 'Harrell', 'F', 'paid'),
#  ('99', 'Ann', 'Banks', 'F', 'free'),
#  ('101', 'Jayden', 'Fox', 'M', 'free'),
#  ('13', 'Ava', 'Robinson', 'F', 'free'),
#  ('14', 'Theodore', 'Harris', 'M', 'free'),
#  ('16', 'Rylan', 'George', 'M', 'paid'),
#  ('20', 'Aiden', 'Ramirez', 'M', 'paid'),
#  ('3', 'Isaac', 'Valdez', 'M', 'free'),
#  ('35', 'Molly', 'Taylor', 'F', 'free'),
#  ('36', 'Matthew', 'Jones', 'M', 'free'),
#  ('4', 'Alivia', 'Terrell', 'F', 'free'),
#  ('45', 'Dominick', 'Norris', 'M', 'free'),
#  ('48', 'Marina', 'Sutton', 'F', 'free'),
#  ('52', 'Theodore', 'Smith', 'M', 'free'),
#  ('56', 'Cienna', 'Freeman', 'F', 'free'),
#  ('57', 'Katherine', 'Gay', 'F', 'free'),
#  ('61', 'Samuel', 'Gonzalez', 'M', 'free'),
#  ('63', 'Ayla', 'Johnson', 'F', 'free'),
#  ('64', 'Hannah', 'Calhoun', 'F', 'free'),
#  ('66', 'Kevin', 'Arellano', 'M', 'free'),
#  ('67', 'Colm', 'Santana', 'M', 'free'),
#  ('68', 'Jordan', 'Rodriguez', 'F', 'free'),
#  ('77', 'Magdalene', 'Herman', 'F', 'free'),
#  ('79', 'James', 'Martin', 'M', 'free'),
#  ('8', 'Kaylee', 'Summers', 'F', 'free'),
#  ('84', 'Shakira', 'Hunt', 'F', 'free'),
#  ('87', 'Dustin', 'Lee', 'M', 'free'),
#  ('91', 'Jayden', 'Bell', 'M', 'free')]

# %%
# %%sql
# SELECT  s.title as title,
#         a.name as artist_name
# FROM songplay_fact sp
# JOIN song_dim s ON ( sp.song_id = s.song_id )
# JOIN artist_dim a ON ( sp.artist_id = a.artist_id);
# Out:
#  * postgresql://awsuser:***@redshift-cluster-2.ccjtiiejbjy6.us-west-2.redshift.amazonaws.com:5439/dev
# 384 rows affected.
# [('Harder Than You Know', 'Escape The Fate'),
#  ('Up Up & Away', 'Kid Cudi / Kanye West / Common'),
#  ('Up Up & Away', 'Kid Cudi'),
#  ('Up Up & Away', 'Kid Cudi / Kanye West / Common'),
#  ('Up Up & Away', 'Kid Cudi'),
#  ('Up Up & Away', 'Kid Cudi / Kanye West / Common'),
#  ('Up Up & Away', 'Kid Cudi'),
#  ('Up Up & Away', 'Kid Cudi / Kanye West / Common'),
#  ('Up Up & Away', 'Kid Cudi'),
#  ('Up Up & Away', 'Kid Cudi / Kanye West / Common'),
#  ('Up Up & Away', 'Kid Cudi'),
#  ("Sorrow's Army", 'Graham Coxon'),
#  ('More Adventurous (Album Version)', 'Rilo Kiley'),
#  ('Handlebars (UK Radio Edit)', 'Flobots'),
#  ('Die Kunst der Fuge_ BWV 1080 (2007 Digital Remaster): Contrapunctus XVII - Inversus', 'Lionel Rogg'),
#  ('My Night With the Prostitute From Marseille', 'Beirut'),
#  ('Thugs Like Me', 'Mia X'),
#  ('From The Ritz To The Rubble', 'Arctic Monkeys'),
#  ('From The Ritz To The Rubble', 'Richard Hawley And Death Ramps_ Arctic Monkeys'),
#  ('From The Ritz To The Rubble', 'Arctic Monkeys'),
#  ('From The Ritz To The Rubble', 'Richard Hawley And Death Ramps_ Arctic Monkeys'),
#  ('From The Ritz To The Rubble', 'Arctic Monkeys'),
#  ('From The Ritz To The Rubble', 'Richard Hawley And Death Ramps_ Arctic Monkeys'),
#  ('Eriatarka', 'The Mars Volta'),
#  ('Never Saw It Coming', 'Hoobastank'),
#  ('World Coming Down', 'Ashbury Heights'),
#  ('Fighters (feat. Matthew Santos) (Amended Album Version)', 'Lupe Fiasco feat. Matthew Santos'),
#  ('Fighters (feat. Matthew Santos) (Amended Album Version)', 'Lupe Fiasco'),
#  ('I Want A New Drug', 'Huey Lewis And The News'),
#  ('I Want A New Drug', 'Huey Lewis & The News'),
#  ('Eye Of The Beholder', 'Metallica'),
#  ("It's Not Easy (Being Green) (Featuring Pierre Bouvier Of Simple Plan)", 'MC Lars'),
#  ("It's Not Easy (Being Green) (Featuring Pierre Bouvier Of Simple Plan)", 'MC Lars (featuring Jaret Reddick)'),
#  ('Get Set For The Blues', 'Julie London'),
#  ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Lonnie Gordon'),
#  ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Lonnie Gordon'),
#  ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Lonnie Gordon'),
#  ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Lonnie Gordon'),
#  ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Lonnie Gordon'),
#  ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Lonnie Gordon'),
#  ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Lonnie Gordon'),
#  ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Lonnie Gordon'),
#  ('Catch You Baby (Steve Pitron & Max Sanna Radio Edit)', 'Lonnie Gordon'),
#  ('My Perfect Cousin', 'The Undertones'),
#  ('Shiny & New', 'Mayer Hawthorne'),
#  ('Nuff Fire', 'Abstract Rude'),
#  ('Suena ("Some Day" end title song "The Hunchback of Notre Dame")', 'Luis Miguel'),
#  ('En Lo Puro No Hay Futuro', 'Jarabe De Palo'),
#  ('Spinning (Album Version)', "Jack's Mannequin featuring Mick Fleetwood"),
#  ('Spinning (Album Version)', "Jack's Mannequin"),
#  ('Panama (Remastered Album Version)', 'Van Halen'),
#  ('Szex & KV', 'Hooligans'),
#  ('No Puedo Evitar (Pensar En Ti)', 'Duncan Dhu'),
#  ('No Puedo Evitar (Pensar En Ti)', 'Duncan Dhu'),
#  ('The Invitation', 'Thousand Foot Krutch'),
#  ('Rozando La Eternidad', 'Duncan Dhu'),
#  ('Strange Times', 'The Black Keys'),
#  ('Ben', 'Jackson 5'),
#  ('Songs Of The Season', 'Soltero'),
#  ('The Moon Asked The Crow', 'Cocorosie'),
#  ('Risque (Album Version)', 'Cute Is What We Aim For'),
#  ("At Least It's Raining", 'Brand New Disaster'),
#  ('Song Sung Blue', 'Neil Diamond'),
#  ('All Of This', 'Blink-182'),
#  ('No Good 4 You', 'Cherise'),
#  ('No Good 4 You', 'Fujiya & Miyagi'),
#  ('Macarena', 'Los Del Rio'),
#  ('The Vision', 'Nocturnal Rites'),
#  ('Ezio In Florence', 'Jesper Kyd'),
#  ('If Looks Could Kill', 'Camera Obscura'),
#  ("I CAN'T GET STARTED", 'Ron Carter'),
#  ("I CAN'T GET STARTED", 'Ron Carter'),
#  ("I CAN'T GET STARTED", 'Ron Carter'),
#  ("I CAN'T GET STARTED", 'Ron Carter'),
#  ("I CAN'T GET STARTED", 'Ron Carter'),
#  ("I CAN'T GET STARTED", 'Ron Carter'),
#  ("I CAN'T GET STARTED", 'Ron Carter'),
#  ("I CAN'T GET STARTED", 'Ron Carter'),
#  ("I CAN'T GET STARTED", 'Ron Carter'),
#  ("Don't Go", 'Starting Rock Feat. Diva Avari'),
#  ('Girlfriend In A Coma', 'The Smiths'),
#  ('Girlfriend In A Coma', 'The Smiths'),
#  ('The Running Man', 'The Audition'),
#  ('Enganchate Conmigo', 'Los Rodriguez'),
#  ('Good Life', 'OneRepublic'),
#  ('Despre tine', 'O-Zone'),
#  ('Bury My Heart', 'The Waterboys'),
#  ('Born To Be Wild', 'Steppenwolf'),
#  ('Born To Be Wild', 'Steppenwolf'),
#  ('Born To Be Wild', 'Steppenwolf'),
#  ('Everything Changes (Album Version)', 'Staind'),
#  ('Setanta matins', 'Elena'),
#  ('Tha', 'Aphex Twin'),
#  ('Tha', 'Polygon Window'),
#  ('Halloween', 'Dead Kennedys'),
#  ('Witness', 'Screaming Trees'),
#  ('Yippiyo-Ay', 'The Presets'),
#  ('Where The Wild Things Were', 'Sounds From The Ground / Tanya Tagaq Gillis'),
#  ('Where The Wild Things Were', 'Sounds from the Ground'),
#  ('Always Attract', 'You Me At Six'),
#  ('Pop Is Dead', 'Radiohead'),
#  ("Let's Get It Started", 'Black Eyed Peas / Terry Dexter'),
#  ("Let's Get It Started", 'Black Eyed Peas / Les Nubians / Mos Def'),
#  ("Let's Get It Started", 'Black Eyed Peas'),
#  ("Let's Get It Started", 'Black Eyed Peas / Terry Dexter'),
#  ("Let's Get It Started", 'Black Eyed Peas / Les Nubians / Mos Def'),
#  ("Let's Get It Started", 'Black Eyed Peas'),
#  ("Let's Get It Started", 'Black Eyed Peas / Terry Dexter'),
#  ("Let's Get It Started", 'Black Eyed Peas / Les Nubians / Mos Def'),
#  ("Let's Get It Started", 'Black Eyed Peas'),
#  ("Wish I Didn't Miss You", 'Angie Stone'),
#  ('Dismantle. Repair.', 'Anberlin'),
#  ('My Everything (Lost In Worship Album Version)', 'Fusebox'),
#  ('Let It Go', 'Keyshia Cole'),
#  ('Let It Go', 'Keyshia Cole / T.I. / Missy Elliott / Young Dro'),
#  ('Club Soda (Album)', 'Ghostland Observatory'),
#  ('Still Waters', 'Jim White'),
#  ('Mia', 'Emmy The Great'),
#  ('Mia', 'Emmy The Great'),
#  ('A New Hope', 'Blink-182'),
#  ('Love My Shake', 'Fukkk Offf'),
#  ('One Way Or Another', 'Kate Voegele'),
#  ('Born In Africa', 'Dr. Alban'),
#  ("What It Ain't", 'Josh Turner'),
#  ("What It Ain't", 'Josh Turner'),
#  ('A Lo Clasico', 'Daddy Yankee'),
#  ('A Lo Clasico', 'Daddy Yankee / Bounty Killer'),
#  ('Stranger Lover', 'Ghostland Observatory'),
#  ('Supermassive Black Hole (Album Version)', 'Muse'),
#  ('Supermassive Black Hole (Album Version)', 'Muse'),
#  ('Supermassive Black Hole (Album Version)', 'Muse'),
#  ('Supermassive Black Hole (Album Version)', 'Muse'),
#  ('Emergency (Album Version)', 'Paramore'),
#  ('Emergency (Album Version)', 'Paramore'),
#  ('Possibilities (The Face Of Love Album Version)', 'Sanctus Real'),
#  ('Fog On The Tyne (Live)', 'Lindisfarne'),
#  ('Starfish-On-The-Toast (2008 Digital Remaster)', 'Donovan'),
#  ('Rebirthing (Album Version)', 'Skillet'),
#  ('Caught Up In You', '38 Special'),
#  ('Caught Up In You', '38 Special'),
#  ('Sun / C79', 'Cat Stevens'),
#  ('Star Eyes', 'Art Pepper'),
#  ('Our Filmscore', 'Nicolai Dunger'),
#  ('Rianna', 'Fisher'),
#  ('Rianna', 'Fisher'),
#  ('Rianna', 'Fisher'),
#  ("If I Ain't Got You", 'Alicia Keys'),
#  ("If I Ain't Got You", 'Alicia Keys'),
#  ("If I Ain't Got You", 'Alicia Keys'),
#  ('The House That Nat Built (Album Version)', 'Kenny Garrett'),
#  ('Beautiful Flower', 'India.Arie'),
#  ('God Smack', 'Alice In Chains'),
#  ('God Smack', 'Alice In Chains'),
#  ('Wax on Tha Belt (Baby G Gets Biz)', 'Mad Flava'),
#  ('A Little Bit Of Love', 'Andreas Johnson'),
#  ('If I Were A Carpenter', 'Robert Plant'),
#  ('Walking On Sunshine', 'Katrina & The Waves'),
#  ('Good Morning Susie Soho', 'Ulf Wakenius'),
#  ('Why', 'Basshunter'),
#  ('Why', 'Basshunter feat. DJ Mental Theos Bazzheadz'),
#  ("Don't Panic", 'Coldplay'),
#  ("Don't Panic", 'Coldplay'),
#  ('Given Up (Album Version)', 'Linkin Park'),
#  ('Given Up (Album Version)', 'Linkin Park'),
#  ('Given Up (Album Version)', 'Linkin Park'),
#  ('Drunk Girls', 'LCD Soundsystem'),
#  ('Sometime Around Midnight', 'The Airborne Toxic Event'),
#  ('Lady', 'Stryper'),
#  ('Not For You', 'Pearl Jam'),
#  ('Shimmy Shimmy Quarter Turn (Take It Back To Square One)', 'Hellogoodbye'),
#  ('Por quererte', 'Efecto Mariposa'),
#  ('Frontline', 'Pillar'),
#  ('Love', 'Musiq'),
#  ("Driver's Seat", "Sniff 'n' The Tears"),
#  ('Fake Tales Of San Francisco', 'Arctic Monkeys'),
#  ('Fake Tales Of San Francisco', 'Richard Hawley And Death Ramps_ Arctic Monkeys'),
#  ('Fake Tales Of San Francisco', 'Arctic Monkeys'),
#  ('Fake Tales Of San Francisco', 'Richard Hawley And Death Ramps_ Arctic Monkeys'),
#  ('Lovefool', 'The Cardigans'),
#  ('Lovefool', 'The Cardigans'),
#  ('Beautiful', 'Goldfrapp'),
#  ('Beautiful', 'Goldfrapp Featuring The Teenagers'),
#  ('Loneliness', 'Tomcraft'),
#  ('Planet Caravan (Remastered LP Version)', 'Pantera'),
#  ('Settle For A Slowdown', 'Dierks Bentley'),
#  ('Till The Sky Falls Down', 'Dash Berlin'),
#  ("St. Patrick's Day", 'John Mayer'),
#  ('One I Love', 'Coldplay'),
#  ('Crawling (Album Version)', 'Linkin Park'),
#  ('Baja por diversion (directo 05)', 'La Fuga'),
#  ('Revolution Deathsquad (Album Version)', 'Dragonforce'),
#  ('The Boy With The Thorn In His Side', 'The Smiths'),
#  ('The Boy With The Thorn In His Side', 'The Smiths'),
#  ('Bang! Bang!', 'The Knux'),
#  ('In A Dead World (Album Version)', 'Killswitch Engage'),
#  ('Marigold', 'Sparklehorse'),
#  ('Fool For Your Loving', 'Whitesnake'),
#  ('One Year_ Six Months', 'Yellowcard'),
#  ('Two Is Better Than One', 'Boys Like Girls'),
#  ('Two Is Better Than One', 'Boys Like Girls featuring Taylor Swift'),
#  ('Human', 'The Human League'),
#  ('Adrenaline', '12 Stones'),
#  ("The Train Kept A Rollin'", 'The Yardbirds'),
#  ('Estoy Enamorado De Ella (Salsa)', 'Limi-T 21'),
#  ('It Was A Good Day', 'Ice Cube Featuring Flavor Flav'),
#  ('It Was A Good Day', 'Ice Cube'),
#  ('Warning', 'Incubus'),
#  ('Missing (Live in Europe)', 'Evanescence'),
#  ("Hey Daddy (Daddy's Home)", 'Usher'),
#  ("Hey Daddy (Daddy's Home)", 'Usher featuring Jermaine Dupri'),
#  ("Hey Daddy (Daddy's Home)", 'Usher'),
#  ("Hey Daddy (Daddy's Home)", 'Usher featuring Jermaine Dupri'),
#  ("Hey Daddy (Daddy's Home)", 'Usher'),
#  ("Hey Daddy (Daddy's Home)", 'Usher featuring Jermaine Dupri'),
#  ("Hey Daddy (Daddy's Home)", 'Usher'),
#  ("Hey Daddy (Daddy's Home)", 'Usher featuring Jermaine Dupri'),
#  ("Hey Daddy (Daddy's Home)", 'Usher'),
#  ("Hey Daddy (Daddy's Home)", 'Usher featuring Jermaine Dupri'),
#  ("Hey Daddy (Daddy's Home)", 'Usher'),
#  ("Hey Daddy (Daddy's Home)", 'Usher featuring Jermaine Dupri'),
#  ('Punk Rock Girl', 'Streetlight Manifesto'),
#  ('Marea (version acustica)', 'Marea'),
#  ('Passenger 10', 'Passenger 10'),
#  ('Mr. Jones', 'Counting Crows'),
#  ('Mr. Jones', 'Counting Crows'),
#  ('Mr. Jones', 'Counting Crows'),
#  ('Mr. Jones', 'Counting Crows'),
#  ('The Raft', 'Fat Freddys Drop'),
#  ('Jumpers (Album)', 'Sleater-kinney'),
#  ('VooDoo', 'Ashanti'),
#  ('VooDoo', 'Ashanti'),
#  ('Something About Mary', 'Wyclef Jean featuring Butch Cassidy and Sharissa'),
#  ('Something About Mary', 'Wyclef Jean'),
#  ('The Door', 'Silverchair'),
#  ('Forgotten', 'Callenish Circle'),
#  ('Valerie', 'Amy Winehouse'),
#  ('15 Step', 'Radiohead'),
#  ('Subterranean Homesick Alien', 'Radiohead'),
#  ('Make Her Say', 'Kid Cudi / Kanye West / Common'),
#  ('Make Her Say', 'Kid Cudi'),
#  ('Make Her Say', 'Kid Cudi / Kanye West / Common'),
#  ('Make Her Say', 'Kid Cudi'),
#  ('Make Her Say', 'Kid Cudi / Kanye West / Common'),
#  ('Make Her Say', 'Kid Cudi'),
#  ('Make Her Say', 'Kid Cudi / Kanye West / Common'),
#  ('Make Her Say', 'Kid Cudi'),
#  ('Make Her Say', 'Kid Cudi / Kanye West / Common'),
#  ('Make Her Say', 'Kid Cudi'),
#  ('The Way I Loved You', 'Taylor Swift'),
#  ('The Way I Loved You', 'Taylor Swift'),
#  ("I'm Not A Loser", 'Descendents'),
#  ('You (w/o Organ Version)', 'Plus One'),
#  ('Dragostea din tin (ma-ya-hi)', 'O-Zone'),
#  ('Manchild', 'Neneh Cherry'),
#  ('Johnny_ I Hardly Knew Ya', 'Dropkick Murphys'),
#  ('Magic', 'Ben Kweller'),
#  ('Astrud Astronette', 'De Phazz'),
#  ('Astrud Astronette', 'De-Phazz'),
#  ('One Woman Man', 'Dave Hollister'),
#  ('Monsoon', 'Jack Johnson'),
#  ('Monsoon', 'Jack Johnson'),
#  ("Please Don't Go", 'No Mercy'),
#  ('Drifting Away', 'Faithless'),
#  ('Heads Will Roll', 'Yeah Yeah Yeahs'),
#  ('One More Lie (Standing In The Shadows)', 'Craig David'),
#  ("Can't Take My Eyes Off You", 'Muse'),
#  ('s.Ada.Licht', 'School Of Seven Bells'),
#  ('Inches And Falling (I Love_ Love) (Live)', 'The Format'),
#  ("Pa' Que Retozen (Amended Version)", 'Tego'),
#  ("Pa' Que Retozen (Amended Version)", 'Tego Calderón'),
#  ("Pa' Que Retozen (Amended Version)", 'Tego Calderon'),
#  ('On A Deeper Level', 'Blufeld'),
#  ("I'm Still Breathing", 'Katy Perry'),
#  ('Exile', 'Enya'),
#  ('Timebomb (LP Version)', "Old 97's"),
#  ('Long Black Road', 'Slim Dusty'),
#  ('Long Black Road', 'Slim Dusty'),
#  ('Two Hearts', 'Phil Collins'),
#  ('La Derrota de Un Don Juan', 'Miguel Morales'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ("You're The One", 'Dwight Yoakam'),
#  ('El Novio Del Olvido', 'Andres Calamaro'),
#  ('Va Bien', 'Soziedad Alkoholika'),
#  ('Hell', 'Foo Fighters'),
#  ("Let's Get Married", 'Jagged Edge featuring Run of Run DMC'),
#  ("Let's Get Married", 'Jagged Edge Featuring Major Damage'),
#  ("Let's Get Married", 'Jagged Edge'),
#  ('English Summer Rain', 'Placebo'),
#  ('I Am Trying to Break Your Heart', 'Wilco'),
#  ('Waterfall (Spirit Of The Rainforest Album Version)', 'David Arkenstone'),
#  ('Waterfall (Spirit Of The Rainforest Album Version)', 'David Arkenstone'),
#  ('Meus Sonhos', 'Bruna Caram'),
#  ('Voodoo Doll', 'Fergie'),
#  ('Crazy', 'Aerosmith'),
#  ('Unwell (Album Version)', 'matchbox twenty'),
#  ('Unwell (Album Version)', 'matchbox twenty'),
#  ('Unwell (Album Version)', 'matchbox twenty'),
#  ('Unwell (Album Version)', 'matchbox twenty'),
#  ('Affliction', 'AFI'),
#  ('Next Hype', 'Tempa T'),
#  ('Atrevido', 'Orishas'),
#  ('Ring My Bell', 'Anita Ward'),
#  ('Kids In America', 'Cascada'),
#  ('Angie (1993 Digital Remaster)', 'The Rolling Stones'),
#  ('Angie (1993 Digital Remaster)', 'The Rolling Stones'),
#  ('O Xote Das Meninas/Asa Branca/Hino A Sao Jose', 'Marisa Monte'),
#  ('You Get What You Give', 'New Radicals'),
#  ('You Get What You Give', 'New Radicals'),
#  ('The Joker', 'Steve Miller Band'),
#  ('Know it All', 'Mac Lethal'),
#  ('Fortunate Fool', 'Jack Johnson'),
#  ('Harder To Breathe', 'Maroon 5'),
#  ('Fade To Black', 'Metallica'),
#  ('Fade To Black', 'Metallica'),
#  ('Fade To Black', 'Metallica'),
#  ('Engel', 'Rammstein'),
#  ('Always Will (LP Version)', 'Tweet'),
#  ('Como La Flor (2005 Re-mastering) (Live)', 'Selena'),
#  ("Almeno Tu Nell'Universo", 'Elisa'),
#  ('I Am The Club (Explicit Album Version)', 'Plies featuring Tank'),
#  ('I Am The Club (Explicit Album Version)', 'Plies'),
#  ('These Words', 'Natasha Bedingfield'),
#  ('Ubangi Stomp', 'Stray Cats'),
#  ('The Mixed Tape (Album Version)', "Jack's Mannequin featuring Mick Fleetwood"),
#  ('The Mixed Tape (Album Version)', "Jack's Mannequin"),
#  ('Pienso En Ti', 'Shakira Featuring Wyclef Jean'),
#  ('Pienso En Ti', 'Shakira'),
#  ('Pienso En Ti', 'Shakira Featuring Wyclef Jean'),
#  ('Pienso En Ti', 'Shakira'),
#  ('Pienso En Ti', 'Shakira Featuring Wyclef Jean'),
#  ('Pienso En Ti', 'Shakira'),
#  ('Paradigm Shift', 'Liquid Tension Experiment'),
#  ('Solar Powered', 'Binary Star'),
#  ("Nothin' On You [feat. Bruno Mars] (Album Version)", 'B.o.B'),
#  ("Nothin' On You [feat. Bruno Mars] (Album Version)", 'B.o.B'),
#  ("Nothin' On You [feat. Bruno Mars] (Album Version)", 'B.o.B'),
#  ("Nothin' On You [feat. Bruno Mars] (Album Version)", 'B.o.B'),
#  ("Nothin' On You [feat. Bruno Mars] (Album Version)", 'B.o.B'),
#  ("Nothin' On You [feat. Bruno Mars] (Album Version)", 'B.o.B'),
#  ("Nothin' On You [feat. Bruno Mars] (Album Version)", 'B.o.B'),
#  ("Nothin' On You [feat. Bruno Mars] (Album Version)", 'B.o.B'),
#  ('Mise En Bouche', 'Prohom'),
#  ('Truly_ Madly_ Deeply', 'Cascada'),
#  ('Dustbowl', 'Horse Feathers'),
#  ('Honey', 'Bobby Goldsboro'),
#  ('The Small Print', 'Muse'),
#  ('Bitter Sweet Symphony', 'The Verve'),
#  ('Bitter Sweet Symphony', 'The Verve'),
#  ('Crazy', 'Pigeon John')]
